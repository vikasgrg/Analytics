# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasgrg/Analytics/blob/main/Confidence_Interval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import stats
import numpy as np
import pandas as pd

# %%
glaxo_df = pd.read_csv('glaxo_df.csv')
glaxo_df.columns = glaxo_df.columns.str.strip()
glaxo_df
# Out:
#             Date               Close      Date.1      gain
# 0            NaN            GLAXO.NS         NaN       NaN
# 1     2010-01-04   619.6060180664062  2010-01-04       NaN
# 2     2010-01-05   616.2327880859375  2010-01-05 -0.005444
# 3     2010-01-06   624.5036010742188  2010-01-06  0.013422
# 4     2010-01-07   628.3912353515625  2010-01-07  0.006225
# ...          ...                 ...         ...       ...
# 1721  2016-12-26  1182.6783447265625  2016-12-26 -0.001284
# 1722  2016-12-27  1173.2335205078125  2016-12-27 -0.007986
# 1723  2016-12-28   1173.406982421875  2016-12-28  0.000148
# 1724  2016-12-29   1184.589111328125  2016-12-29  0.009530
# 1725  2016-12-30   1185.414306640625  2016-12-30  0.000697
#
# [1726 rows x 4 columns]

# %%
glaxo_df_ci = stats.norm.interval(0.99,
loc = glaxo_df.gain.mean(),
scale = glaxo_df.gain.std())

print( 'Mean at 95% confidence interval is:', np.round(glaxo_df_ci, 4))
# Out:
# Mean at 95% confidence interval is: [-0.034   0.0349]

# %%
# Out:
#           version https://git-lfs.github.com/spec/v1
# 0  oid sha256:1742f5044c54488e332d6089e2d701c3e3f...
# 1                                         size 90678

# %%
glaxo_df.shape[0]-1
# Out:
# 1725

# %%
glaxo_df_ci = stats.t.interval(0.95,
loc = glaxo_df.gain.mean(),
scale = glaxo_df.gain.std(), df=1725)

print( 'Mean at 95% confidence interval is:', np.round(glaxo_df_ci, 4))
# Out:
# Mean at 95% confidence interval is: [-0.0258  0.0267]
